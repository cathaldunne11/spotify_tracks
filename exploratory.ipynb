# %% [markdown]
# ### Exploratory analysis on the spotify_tracks dataset

# %%
# import required libraries
import pandas as pd
import seaborn as sns
import os

# %%
# define a function that is useful for quickly saving a pandas dataframe to an excel
import os
import string
import pandas as pd

def df_xl(df, base_name="data_output"):
    """
    Saves a DataFrame to the 'datasets' folder with incremental alphabetical filenames
    (a–z), then numeric ones (1, 2, 3...).
    Example:
        data_output_a.xlsx, data_output_b.xlsx, ..., data_output_z.xlsx, data_output_1.xlsx, ...
    """

    # Ensure the 'datasets' folder exists
    os.makedirs('datasets', exist_ok=True)

    # List existing files in the folder
    existing_files = [f for f in os.listdir('datasets') if f.startswith(base_name) and f.endswith('.xlsx')]

    # Determine the next filename
    used_suffixes = set()
    for f in existing_files:
        suffix = f[len(base_name):-5]  # remove prefix and .xlsx
        if suffix.startswith("_"):
            suffix = suffix[1:]  # remove leading underscore
        used_suffixes.add(suffix)

    # Generate the next suffix (a–z, then numbers)
    next_suffix = None
    for letter in string.ascii_lowercase:  # a–z
        if letter not in used_suffixes:
            next_suffix = letter
            break
    if next_suffix is None:
        # All letters used — find next number
        numbers = [int(s) for s in used_suffixes if s.isdigit()]
        next_suffix = str(max(numbers) + 1 if numbers else 1)

    # Build the filename and path
    filename = f"{base_name}_{next_suffix}.xlsx"
    output_path = os.path.join(os.getcwd(), "datasets", filename)

    # Save the DataFrame
    df.to_excel(output_path, index=False)
    print(f"DataFrame saved to: {output_path}")

# %%
# import the spotify tracks dataset
tracks_df = pd.read_csv("datasets/dataset.csv")

# %%
print(tracks_df.head())
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
# The file has 114k records, so create a sample of the dataset, that I can more easily look at and understand it in excel within VSCode

# take a sample of 5,000 records
tracks_sample_df = tracks_df.sample(n = 5000, random_state = 42) # set the random state for reproducibility

# save to excel in the working folder
output_path = os.path.join(os.getcwd(), "datasets", "dataset_5ksample.xlsx")
tracks_sample_df.to_excel(output_path, index = False)

# %%
# understand dataset structure
print(tracks_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 17.5+ MB
# None

# %%
# Make sure that the field track_id is a unique primary index

# how many records in the dataset?
print(tracks_df.shape) # 114,000

# how many unique track_ids are there
print(tracks_df['track_id'].nunique())  # 89,741 (so a lot of duplication at track_id). investigate this next
# Out:
# (114000, 21)
# 89741

# %%
# create a dataframe showing the number of occurrences of each track_id
track_id_agg_df = tracks_df['track_id'].value_counts().reset_index()
track_id_agg_df.columns = ['track_id', 'num_occ']
print(track_id_agg_df.head())
# Out:
#                  track_id  num_occ
# 0  6S3JlDAGk3uu3NtZbPnuhS        9
# 1  2Ey6v4Sekh3Z0RUSISRosD        8
# 2  2kkvB3RNRzwjFdGhaUA0tz        8
# 3  2vU6bm5hVF2idVknGzqyPL        7
# 4  5ZsAhuQ24mWHiduaxJqnhW        7

# %%
# aggregate this further to show how many track_ids have how many occurrences
track_id_agg_df_agg  = track_id_agg_df['num_occ'].value_counts().reset_index()
track_id_agg_df_agg.columns = ['num_occ', 'num_track_id']
track_id_agg_df_agg.sort_values('num_occ', ascending = True)
track_id_agg_df_agg['cumsum_num_track_id'] = track_id_agg_df_agg['num_track_id'].cumsum()
track_id_agg_df_agg['prop'] = track_id_agg_df_agg['num_track_id'] / track_id_agg_df_agg['num_track_id'].sum()
track_id_agg_df_agg['cumsum_prop'] = track_id_agg_df_agg['prop'].cumsum()
print(track_id_agg_df_agg)
# Out:
#    num_occ  num_track_id  cumsum_num_track_id      prop  cumsum_prop
# 0        1         73100                73100  0.814566     0.814566
# 1        2         11712                84812  0.130509     0.945075
# 2        3          2984                87796  0.033251     0.978327
# 3        4          1372                89168  0.015288     0.993615
# 4        5           431                89599  0.004803     0.998418
# 5        6           117                89716  0.001304     0.999721
# 6        7            22                89738  0.000245     0.999967
# 7        8             2                89740  0.000022     0.999989
# 8        9             1                89741  0.000011     1.000000

# %%
# only 81% of the track ids are unique, but 99% have 4 or less occurences
# take a sample of the duplicates to begin figuring out some strategies for handling this issue

# %%
# create a random sample  of duplicate track_ids
track_id_dup = track_id_agg_df[track_id_agg_df['num_occ'] > 1]
print(track_id_dup.head(10))
# sort it to make sure there's no 1s
track_id_dup.sort_values('num_occ', ascending = True)
# all good
# Out:
#                  track_id  num_occ
# 0  6S3JlDAGk3uu3NtZbPnuhS        9
# 1  2Ey6v4Sekh3Z0RUSISRosD        8
# 2  2kkvB3RNRzwjFdGhaUA0tz        8
# 3  2vU6bm5hVF2idVknGzqyPL        7
# 4  5ZsAhuQ24mWHiduaxJqnhW        7
# 5  4XYieGKSlJlHpzB3bl6WMP        7
# 6  3dJjsWCy6ZwMfw5NbD226G        7
# 7  0YLSjVxSb5FT1Bo8Tnxr8j        7
# 8  4aqS25F3ywJ9TGnNkOqilC        7
# 9  0e5LcankE0UyJUuCoq1uH2        7
#                      track_id  num_occ
# 16624  27nGU2v3syK7aU3AVY2vUO        2
# 16625  2TgTGJyiWf1ptW5g3QG938        2
# 16626  63vjnB6EeQuVf64zLxIo90        2
# 16627  0sSjIvTvd6fUSZZ5rnTPDW        2
# 16628  2zg3iJW4fK7KZgHOvJU67z        2
# ...                       ...      ...
# 17     08kTa3SL9sV6Iy8KLKtGql        7
# 22     4GPQDyw9hC1DiZVh0ouDVL        7
# 1      2Ey6v4Sekh3Z0RUSISRosD        8
# 2      2kkvB3RNRzwjFdGhaUA0tz        8
# 0      6S3JlDAGk3uu3NtZbPnuhS        9
#
# [16641 rows x 2 columns]

# %%
# take 20 at random
dup_tracks_sample = track_id_dup.sample(n = 20, random_state = 58) # set the random state for reproducibility
print(dup_tracks_sample)
# Out:
#                      track_id  num_occ
# 1976   3McXs3tqyP5VwBg4FdiILD        3
# 1844   2GqmufsIytFAXE9sxz4m4S        4
# 12003  3rGol3Ivk8X9fvzKL0U8ih        2
# 350    3AedlLCGKNhQdhtLzObIbR        5
# 61     1ycq2btx7kf6bXdWILZhXa        6
# 5952   22sQUmLhT8umlEhQzDrzfJ        2
# 15270  4XSpyx2fV1c9Iq9TYY2zXk        2
# 16067  4SeZpWSgq1c8a0MY3iVy1f        2
# 8637   6FOZMPsV4o3dMj7juFrXMT        2
# 10468  0zqBZqm5czQ3A4EoSdKFHj        2
# 4378   1ErVAnzjNvyXSodWbOTYNu        3
# 7208   46jni4B6gnRB5EbjIEnsf3        2
# 10030  7lUB18zW8flnzCpHmIA0lL        2
# 6656   46RvocxUkMUhCtDxk1BUyT        2
# 7947   2YNgcIiD73XsXFNM3UuxlM        2
# 666    5ln5yQdUywVbf8HhFsOcd6        4
# 15379  1DIGB5kZKiHnEb2uWxzjzY        2
# 3079   0E9ZjEAyAwOXZ7wJC0PD33        3
# 13953  3qNERYCjkBFyhYUNh4Hl9K        2
# 920    4jJ3rcbPevOdXr6hFIVW45        4

# %%
tracks_df_dup = tracks_df[tracks_df['track_id'].isin(dup_tracks_sample['track_id'])] 
tracks_df_dup.sort_values(by = 'track_id', ascending = True)

print(tracks_df_dup)
# Out:
#         Unnamed: 0                track_id                        artists  \
# 5867          5867  22sQUmLhT8umlEhQzDrzfJ                           Reol
# 9331          9331  6FOZMPsV4o3dMj7juFrXMT                    Juliano Son
# 20259        20259  5ln5yQdUywVbf8HhFsOcd6                         Halsey
# 21143        21143  3McXs3tqyP5VwBg4FdiILD        Vybz Kartel;Arif Cooper
# 23143        23143  46jni4B6gnRB5EbjIEnsf3                      BLOND:ISH
# 25277        25277  46jni4B6gnRB5EbjIEnsf3                      BLOND:ISH
# 26165        26165  7lUB18zW8flnzCpHmIA0lL                      Jon Sarta
# 28105        28105  46RvocxUkMUhCtDxk1BUyT            ILLENIUM;Dana Salah
# 29060        29060  46RvocxUkMUhCtDxk1BUyT            ILLENIUM;Dana Salah
# 30518        30518  0E9ZjEAyAwOXZ7wJC0PD33         Dynoro;Gigi D'Agostino
# 31025        31025  5ln5yQdUywVbf8HhFsOcd6                         Halsey
# 31118        31118  0zqBZqm5czQ3A4EoSdKFHj  Alan Walker;Benjamin Ingrosso
# 31572        31572  0E9ZjEAyAwOXZ7wJC0PD33         Dynoro;Gigi D'Agostino
# 34093        34093  2YNgcIiD73XsXFNM3UuxlM                 Salim–Sulaiman
# 40119        40119  6FOZMPsV4o3dMj7juFrXMT                    Juliano Son
# 48483        48483  4jJ3rcbPevOdXr6hFIVW45                Swingin' Utters
# 51197        51197  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 53114        53114  0zqBZqm5czQ3A4EoSdKFHj  Alan Walker;Benjamin Ingrosso
# 53361        53361  0E9ZjEAyAwOXZ7wJC0PD33         Dynoro;Gigi D'Agostino
# 55435        55435  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 55497        55497  2YNgcIiD73XsXFNM3UuxlM                 Salim–Sulaiman
# 56035        56035  5ln5yQdUywVbf8HhFsOcd6                         Halsey
# 56134        56134  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 57076        57076  5ln5yQdUywVbf8HhFsOcd6                         Halsey
# 57178        57178  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 60043        60043  3McXs3tqyP5VwBg4FdiILD        Vybz Kartel;Arif Cooper
# 62292        62292  3rGol3Ivk8X9fvzKL0U8ih                   Jamie Cullum
# 63702        63702  22sQUmLhT8umlEhQzDrzfJ                           Reol
# 64590        64590  3rGol3Ivk8X9fvzKL0U8ih                   Jamie Cullum
# 65412        65412  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 67039        67039  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 67770        67770  2GqmufsIytFAXE9sxz4m4S    J Alvarez;Sak Luke;DJ Valdi
# 67784        67784  1ErVAnzjNvyXSodWbOTYNu                 Greeicy;Anitta
# 68142        68142  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 68537        68537  2GqmufsIytFAXE9sxz4m4S    J Alvarez;Sak Luke;DJ Valdi
# 74746        74746  3qNERYCjkBFyhYUNh4Hl9K                 Maria Bethânia
# 79939        79939  7lUB18zW8flnzCpHmIA0lL                      Jon Sarta
# 82132        82132  4jJ3rcbPevOdXr6hFIVW45                Swingin' Utters
# 85581        85581  4XSpyx2fV1c9Iq9TYY2zXk          Chingadazo de Kung Fu
# 86787        86787  4XSpyx2fV1c9Iq9TYY2zXk          Chingadazo de Kung Fu
# 86919        86919  1DIGB5kZKiHnEb2uWxzjzY       Big D and the Kids Table
# 86974        86974  4jJ3rcbPevOdXr6hFIVW45                Swingin' Utters
# 88182        88182  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 88540        88540  2GqmufsIytFAXE9sxz4m4S    J Alvarez;Sak Luke;DJ Valdi
# 88542        88542  1ErVAnzjNvyXSodWbOTYNu                 Greeicy;Anitta
# 88688        88688  3McXs3tqyP5VwBg4FdiILD        Vybz Kartel;Arif Cooper
# 89171        89171  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 89493        89493  1ErVAnzjNvyXSodWbOTYNu                 Greeicy;Anitta
# 89543        89543  2GqmufsIytFAXE9sxz4m4S    J Alvarez;Sak Luke;DJ Valdi
# 96479        96479  3qNERYCjkBFyhYUNh4Hl9K                 Maria Bethânia
# 99077        99077  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 99270        99270  4SeZpWSgq1c8a0MY3iVy1f                      Zach Hood
# 100373      100373  1DIGB5kZKiHnEb2uWxzjzY       Big D and the Kids Table
# 100558      100558  4jJ3rcbPevOdXr6hFIVW45                Swingin' Utters
# 102076      102076  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 102271      102271  4SeZpWSgq1c8a0MY3iVy1f                      Zach Hood
#
#                                                album_name  \
# 5867                                                  第六感
# 9331                                Mais um Dia (ao Vivo)
# 20259                  hopeless fountain kingdom (Deluxe)
# 21143   Arif Cooper Presents: Up & Live Riddim (2022 R...
# 23143                                   #PlasticFreeParty
# 25277                                   #PlasticFreeParty
# 26165                 Piano Lullabies for Bedtime, Vol. 3
# 28105                                               Ashes
# 29060                                               Ashes
# 30518                                          In My Mind
# 31025                  hopeless fountain kingdom (Deluxe)
# 31118                                     World Of Walker
# 31572                                          In My Mind
# 34093                      Rab Ne Bana Di Jodi (Original)
# 40119                               Mais um Dia (ao Vivo)
# 48483             A Juvenile Product of the Working Class
# 51197                         Queda poco para la PAES 2.0
# 53114                                     World Of Walker
# 53361                                          In My Mind
# 55435                                                Piku
# 55497                      Rab Ne Bana Di Jodi (Original)
# 56035                  hopeless fountain kingdom (Deluxe)
# 56134                                                Piku
# 57076                  hopeless fountain kingdom (Deluxe)
# 57178                                                Piku
# 60043   Arif Cooper Presents: Up & Live Riddim (2022 R...
# 62292              Rockin' Around The Christmas Tree 2022
# 63702                                                 第六感
# 64590              Rockin' Around The Christmas Tree 2022
# 65412                                                Piku
# 67039                         Queda poco para la PAES 2.0
# 67770                                Caribe Mix Reggaeton
# 67784                        Halloween 2022 Perreo Vol. 1
# 68142                         Queda poco para la PAES 2.0
# 68537                                Caribe Mix Reggaeton
# 74746     As Grandes Décadas Da Música Popular Brasileira
# 79939                 Piano Lullabies for Bedtime, Vol. 3
# 82132             A Juvenile Product of the Working Class
# 85581                           Orinando Contra el Viento
# 86787                           Orinando Contra el Viento
# 86919                                         How It Goes
# 86974             A Juvenile Product of the Working Class
# 88182                         Queda poco para la PAES 2.0
# 88540                                Caribe Mix Reggaeton
# 88542                        Halloween 2022 Perreo Vol. 1
# 88688   Arif Cooper Presents: Up & Live Riddim (2022 R...
# 89171                         Queda poco para la PAES 2.0
# 89493                        Halloween 2022 Perreo Vol. 1
# 89543                                Caribe Mix Reggaeton
# 96479     As Grandes Décadas Da Música Popular Brasileira
# 99077                                                Piku
# 99270                                          Flashbacks
# 100373                                        How It Goes
# 100558            A Juvenile Product of the Working Class
# 102076                                               Piku
# 102271                                         Flashbacks
#
#                                            track_name  popularity  \
# 5867                                              第六感          60
# 9331                       Vai Valer a Pena - Ao Vivo          47
# 20259                                Walls Could Talk          77
# 21143   Good Body Wine (2022 Remastered) - Radio Edit           0
# 23143                                      Life Is...           0
# 25277                                      Life Is...           0
# 26165                         Angels Watching over Me          28
# 28105                                         Reverie          51
# 29060                                         Reverie          51
# 30518                                      In My Mind          79
# 31025                                Walls Could Talk          77
# 31118                                 Man On The Moon          73
# 31572                                      In My Mind          79
# 34093                                    Dancing Jodi          50
# 40119                      Vai Valer a Pena - Ao Vivo          47
# 48483                               Windspitting Punk          35
# 51197                                        Pasarela           0
# 53114                                 Man On The Moon          73
# 53361                                      In My Mind          79
# 55435                                        Bezubaan          53
# 55497                                    Dancing Jodi          50
# 56035                                Walls Could Talk          77
# 56134                                        Bezubaan          53
# 57076                                Walls Could Talk          77
# 57178                                        Bezubaan          53
# 60043   Good Body Wine (2022 Remastered) - Radio Edit           0
# 62292                               Show Me The Magic           0
# 63702                                             第六感          60
# 64590                               Show Me The Magic           0
# 65412                                        Bezubaan          53
# 67039                                        Pasarela           0
# 67770                                       Loka Loka           0
# 67784                                         Jacuzzi           0
# 68142                                        Pasarela           0
# 68537                                       Loka Loka           0
# 74746                                         Carcará          39
# 79939                         Angels Watching over Me          28
# 82132                               Windspitting Punk          35
# 85581                           Intento Fallido No. 7          38
# 86787                           Intento Fallido No. 7          38
# 86919                                    Little Bitch          35
# 86974                               Windspitting Punk          35
# 88182                                        Pasarela           0
# 88540                                       Loka Loka           0
# 88542                                         Jacuzzi           0
# 88688   Good Body Wine (2022 Remastered) - Radio Edit           0
# 89171                                        Pasarela           0
# 89493                                         Jacuzzi           0
# 89543                                       Loka Loka           0
# 96479                                         Carcará          39
# 99077                                        Bezubaan          53
# 99270                                      Flashbacks          67
# 100373                                   Little Bitch          35
# 100558                              Windspitting Punk          35
# 102076                                       Bezubaan          53
# 102271                                     Flashbacks          67
#
#         duration_ms  explicit  danceability  energy  ...  loudness  mode  \
# 5867         191624     False         0.675  0.9590  ...    -1.754     1
# 9331         297365     False         0.313  0.8690  ...    -4.113     1
# 20259        101789      True         0.626  0.4230  ...    -6.035     1
# 21143        181266     False         0.707  0.9040  ...    -4.091     0
# 23143        253701     False         0.698  0.8610  ...    -7.210     1
# 25277        253701     False         0.698  0.8610  ...    -7.210     1
# 26165        157418     False         0.729  0.0201  ...   -19.780     1
# 28105        299656     False         0.376  0.6920  ...    -4.474     1
# 29060        299656     False         0.376  0.6920  ...    -4.474     1
# 30518        184560     False         0.694  0.7700  ...    -5.335     1
# 31025        101789      True         0.626  0.4230  ...    -6.035     1
# 31118        178625     False         0.668  0.8160  ...    -5.648     0
# 31572        184560     False         0.694  0.7700  ...    -5.335     1
# 34093        239647     False         0.704  0.9030  ...    -7.384     0
# 40119        297365     False         0.313  0.8690  ...    -4.113     1
# 48483        134800     False         0.284  0.9590  ...    -6.020     0
# 51197        193733     False         0.839  0.9070  ...    -4.259     1
# 53114        178625     False         0.668  0.8160  ...    -5.648     0
# 53361        184560     False         0.694  0.7700  ...    -5.335     1
# 55435        341177     False         0.403  0.5600  ...    -7.460     1
# 55497        239647     False         0.704  0.9030  ...    -7.384     0
# 56035        101789      True         0.626  0.4230  ...    -6.035     1
# 56134        341177     False         0.403  0.5600  ...    -7.460     1
# 57076        101789      True         0.626  0.4230  ...    -6.035     1
# 57178        341177     False         0.403  0.5600  ...    -7.460     1
# 60043        181266     False         0.707  0.9040  ...    -4.091     0
# 62292        150412     False         0.569  0.4890  ...    -5.594     0
# 63702        191624     False         0.675  0.9590  ...    -1.754     1
# 64590        150412     False         0.569  0.4890  ...    -5.594     0
# 65412        341177     False         0.403  0.5600  ...    -7.460     1
# 67039        193733     False         0.839  0.9070  ...    -4.259     1
# 67770        210093     False         0.775  0.7940  ...    -4.167     0
# 67784        184106     False         0.821  0.7360  ...    -4.484     0
# 68142        193733     False         0.839  0.9070  ...    -4.259     1
# 68537        210093     False         0.775  0.7940  ...    -4.167     0
# 74746        163160     False         0.653  0.6790  ...    -7.354     0
# 79939        157418     False         0.729  0.0201  ...   -19.780     1
# 82132        134800     False         0.284  0.9590  ...    -6.020     0
# 85581        201069      True         0.442  0.8970  ...    -7.100     1
# 86787        201069      True         0.442  0.8970  ...    -7.100     1
# 86919        137773     False         0.444  0.9530  ...    -1.644     1
# 86974        134800     False         0.284  0.9590  ...    -6.020     0
# 88182        193733     False         0.839  0.9070  ...    -4.259     1
# 88540        210093     False         0.775  0.7940  ...    -4.167     0
# 88542        184106     False         0.821  0.7360  ...    -4.484     0
# 88688        181266     False         0.707  0.9040  ...    -4.091     0
# 89171        193733     False         0.839  0.9070  ...    -4.259     1
# 89493        184106     False         0.821  0.7360  ...    -4.484     0
# 89543        210093     False         0.775  0.7940  ...    -4.167     0
# 96479        163160     False         0.653  0.6790  ...    -7.354     0
# 99077        341177     False         0.403  0.5600  ...    -7.460     1
# 99270        183000     False         0.550  0.4480  ...    -7.382     1
# 100373       137773     False         0.444  0.9530  ...    -1.644     1
# 100558       134800     False         0.284  0.9590  ...    -6.020     0
# 102076       341177     False         0.403  0.5600  ...    -7.460     1
# 102271       183000     False         0.550  0.4480  ...    -7.382     1
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 5867         0.0835      0.008930          0.000085    0.3250   0.8350
# 9331         0.0508      0.133000          0.001740    0.7030   0.2210
# 20259        0.0513      0.128000          0.000000    0.1800   0.5710
# 21143        0.1480      0.130000          0.000000    0.2570   0.8230
# 23143        0.0344      0.000237          0.471000    0.0758   0.1690
# 25277        0.0344      0.000237          0.471000    0.0758   0.1690
# 26165        0.0465      0.994000          0.927000    0.1060   0.2800
# 28105        0.0558      0.019700          0.000393    0.1110   0.0903
# 29060        0.0558      0.019700          0.000393    0.1110   0.0903
# 30518        0.1490      0.176000          0.000011    0.1180   0.1630
# 31025        0.0513      0.128000          0.000000    0.1800   0.5710
# 31118        0.0367      0.055700          0.000001    0.1970   0.5000
# 31572        0.1490      0.176000          0.000011    0.1180   0.1630
# 34093        0.0879      0.015900          0.572000    0.0818   0.6510
# 40119        0.0508      0.133000          0.001740    0.7030   0.2210
# 48483        0.1230      0.001420          0.000146    0.0866   0.6650
# 51197        0.0453      0.101000          0.000000    0.3320   0.7370
# 53114        0.0367      0.055700          0.000001    0.1970   0.5000
# 53361        0.1490      0.176000          0.000011    0.1180   0.1630
# 55435        0.0362      0.354000          0.000006    0.1250   0.1680
# 55497        0.0879      0.015900          0.572000    0.0818   0.6510
# 56035        0.0513      0.128000          0.000000    0.1800   0.5710
# 56134        0.0362      0.354000          0.000006    0.1250   0.1680
# 57076        0.0513      0.128000          0.000000    0.1800   0.5710
# 57178        0.0362      0.354000          0.000006    0.1250   0.1680
# 60043        0.1480      0.130000          0.000000    0.2570   0.8230
# 62292        0.0400      0.238000          0.000000    0.2900   0.5430
# 63702        0.0835      0.008930          0.000085    0.3250   0.8350
# 64590        0.0400      0.238000          0.000000    0.2900   0.5430
# 65412        0.0362      0.354000          0.000006    0.1250   0.1680
# 67039        0.0453      0.101000          0.000000    0.3320   0.7370
# 67770        0.0486      0.162000          0.000000    0.3370   0.8400
# 67784        0.0669      0.091400          0.000000    0.0542   0.9410
# 68142        0.0453      0.101000          0.000000    0.3320   0.7370
# 68537        0.0486      0.162000          0.000000    0.3370   0.8400
# 74746        0.0714      0.673000          0.000441    0.6080   0.8770
# 79939        0.0465      0.994000          0.927000    0.1060   0.2800
# 82132        0.1230      0.001420          0.000146    0.0866   0.6650
# 85581        0.0439      0.013000          0.012000    0.1680   0.5750
# 86787        0.0439      0.013000          0.012000    0.1680   0.5750
# 86919        0.1990      0.023000          0.000000    0.1440   0.6090
# 86974        0.1230      0.001420          0.000146    0.0866   0.6650
# 88182        0.0453      0.101000          0.000000    0.3320   0.7370
# 88540        0.0486      0.162000          0.000000    0.3370   0.8400
# 88542        0.0669      0.091400          0.000000    0.0542   0.9410
# 88688        0.1480      0.130000          0.000000    0.2570   0.8230
# 89171        0.0453      0.101000          0.000000    0.3320   0.7370
# 89493        0.0669      0.091400          0.000000    0.0542   0.9410
# 89543        0.0486      0.162000          0.000000    0.3370   0.8400
# 96479        0.0714      0.673000          0.000441    0.6080   0.8770
# 99077        0.0362      0.354000          0.000006    0.1250   0.1680
# 99270        0.0314      0.879000          0.000000    0.0734   0.4900
# 100373       0.1990      0.023000          0.000000    0.1440   0.6090
# 100558       0.1230      0.001420          0.000146    0.0866   0.6650
# 102076       0.0362      0.354000          0.000006    0.1250   0.1680
# 102271       0.0314      0.879000          0.000000    0.0734   0.4900
#
#           tempo  time_signature        track_genre
# 5867    134.017               4              anime
# 9331    127.875               4             brazil
# 20259    95.162               4              dance
# 21143    86.708               5          dancehall
# 23143   123.004               4         deep-house
# 25277   123.004               4              disco
# 26165    78.051               4             disney
# 28105   173.899               4                dub
# 29060   173.899               4            dubstep
# 30518   125.905               4                edm
# 31025    95.162               4            electro
# 31118   129.971               4            electro
# 31572   125.905               4            electro
# 34093   131.988               4               folk
# 40119   127.875               4             gospel
# 48483   174.296               4           hardcore
# 51197   121.048               4            hip-hop
# 53114   129.971               4              house
# 53361   125.905               4              house
# 55435   155.701               4             indian
# 55497   131.988               4             indian
# 56035    95.162               4          indie-pop
# 56134   155.701               4          indie-pop
# 57076    95.162               4              indie
# 57178   155.701               4              indie
# 60043    86.708               5            j-dance
# 62292   123.573               4              j-pop
# 63702   134.017               4             j-rock
# 64590   123.573               4               jazz
# 65412   155.701               4              k-pop
# 67039   121.048               4              latin
# 67770    94.018               4              latin
# 67784    93.008               4              latin
# 68142   121.048               4             latino
# 68537    94.018               4             latino
# 74746   130.964               4                mpb
# 79939    78.051               4              piano
# 82132   174.296               4          power-pop
# 85581   102.536               4          punk-rock
# 86787   102.536               4               punk
# 86919   189.790               4               punk
# 86974   174.296               4               punk
# 88182   121.048               4             reggae
# 88540    94.018               4             reggae
# 88542    93.008               4             reggae
# 88688    86.708               5             reggae
# 89171   121.048               4          reggaeton
# 89493    93.008               4          reggaeton
# 89543    94.018               4          reggaeton
# 96479   130.964               4              samba
# 99077   155.701               4  singer-songwriter
# 99270    99.713               4  singer-songwriter
# 100373  189.790               4                ska
# 100558  174.296               4                ska
# 102076  155.701               4         songwriter
# 102271   99.713               4         songwriter
#
# [56 rows x 21 columns]

# %%
# that sorting didn't work, since they're alphanumeric. try again
import re

# Extract leading number
tracks_df_dup['numeric_prefix'] = tracks_df_dup['track_id'].str.extract(r'^(\d+)').astype(int)

# Sort by numeric prefix first, then full string
tracks_df_dup.sort_values(by=['numeric_prefix', 'track_id'], inplace=True)

# Optional: drop helper column
tracks_df_dup.drop(columns='numeric_prefix', inplace=True)
# Out:
# C:\Users\Anne\AppData\Local\Temp\ipykernel_12916\2776651592.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tracks_df_dup['numeric_prefix'] = tracks_df_dup['track_id'].str.extract(r'^(\d+)').astype(int)
# C:\Users\Anne\AppData\Local\Temp\ipykernel_12916\2776651592.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tracks_df_dup.sort_values(by=['numeric_prefix', 'track_id'], inplace=True)
# C:\Users\Anne\AppData\Local\Temp\ipykernel_12916\2776651592.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tracks_df_dup.drop(columns='numeric_prefix', inplace=True)

# %%
print(tracks_df_dup)
# Out:
#         Unnamed: 0                track_id                        artists  \
# 30518        30518  0E9ZjEAyAwOXZ7wJC0PD33         Dynoro;Gigi D'Agostino
# 31572        31572  0E9ZjEAyAwOXZ7wJC0PD33         Dynoro;Gigi D'Agostino
# 53361        53361  0E9ZjEAyAwOXZ7wJC0PD33         Dynoro;Gigi D'Agostino
# 31118        31118  0zqBZqm5czQ3A4EoSdKFHj  Alan Walker;Benjamin Ingrosso
# 53114        53114  0zqBZqm5czQ3A4EoSdKFHj  Alan Walker;Benjamin Ingrosso
# 86919        86919  1DIGB5kZKiHnEb2uWxzjzY       Big D and the Kids Table
# 100373      100373  1DIGB5kZKiHnEb2uWxzjzY       Big D and the Kids Table
# 67784        67784  1ErVAnzjNvyXSodWbOTYNu                 Greeicy;Anitta
# 88542        88542  1ErVAnzjNvyXSodWbOTYNu                 Greeicy;Anitta
# 89493        89493  1ErVAnzjNvyXSodWbOTYNu                 Greeicy;Anitta
# 55435        55435  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 56134        56134  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 57178        57178  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 65412        65412  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 99077        99077  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 102076      102076  1ycq2btx7kf6bXdWILZhXa                     Anupam Roy
# 67770        67770  2GqmufsIytFAXE9sxz4m4S    J Alvarez;Sak Luke;DJ Valdi
# 68537        68537  2GqmufsIytFAXE9sxz4m4S    J Alvarez;Sak Luke;DJ Valdi
# 88540        88540  2GqmufsIytFAXE9sxz4m4S    J Alvarez;Sak Luke;DJ Valdi
# 89543        89543  2GqmufsIytFAXE9sxz4m4S    J Alvarez;Sak Luke;DJ Valdi
# 34093        34093  2YNgcIiD73XsXFNM3UuxlM                 Salim–Sulaiman
# 55497        55497  2YNgcIiD73XsXFNM3UuxlM                 Salim–Sulaiman
# 51197        51197  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 67039        67039  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 68142        68142  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 88182        88182  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 89171        89171  3AedlLCGKNhQdhtLzObIbR                   Daddy Yankee
# 21143        21143  3McXs3tqyP5VwBg4FdiILD        Vybz Kartel;Arif Cooper
# 60043        60043  3McXs3tqyP5VwBg4FdiILD        Vybz Kartel;Arif Cooper
# 88688        88688  3McXs3tqyP5VwBg4FdiILD        Vybz Kartel;Arif Cooper
# 74746        74746  3qNERYCjkBFyhYUNh4Hl9K                 Maria Bethânia
# 96479        96479  3qNERYCjkBFyhYUNh4Hl9K                 Maria Bethânia
# 62292        62292  3rGol3Ivk8X9fvzKL0U8ih                   Jamie Cullum
# 64590        64590  3rGol3Ivk8X9fvzKL0U8ih                   Jamie Cullum
# 99270        99270  4SeZpWSgq1c8a0MY3iVy1f                      Zach Hood
# 102271      102271  4SeZpWSgq1c8a0MY3iVy1f                      Zach Hood
# 85581        85581  4XSpyx2fV1c9Iq9TYY2zXk          Chingadazo de Kung Fu
# 86787        86787  4XSpyx2fV1c9Iq9TYY2zXk          Chingadazo de Kung Fu
# 48483        48483  4jJ3rcbPevOdXr6hFIVW45                Swingin' Utters
# 82132        82132  4jJ3rcbPevOdXr6hFIVW45                Swingin' Utters
# 86974        86974  4jJ3rcbPevOdXr6hFIVW45                Swingin' Utters
# 100558      100558  4jJ3rcbPevOdXr6hFIVW45                Swingin' Utters
# 20259        20259  5ln5yQdUywVbf8HhFsOcd6                         Halsey
# 31025        31025  5ln5yQdUywVbf8HhFsOcd6                         Halsey
# 56035        56035  5ln5yQdUywVbf8HhFsOcd6                         Halsey
# 57076        57076  5ln5yQdUywVbf8HhFsOcd6                         Halsey
# 9331          9331  6FOZMPsV4o3dMj7juFrXMT                    Juliano Son
# 40119        40119  6FOZMPsV4o3dMj7juFrXMT                    Juliano Son
# 26165        26165  7lUB18zW8flnzCpHmIA0lL                      Jon Sarta
# 79939        79939  7lUB18zW8flnzCpHmIA0lL                      Jon Sarta
# 5867          5867  22sQUmLhT8umlEhQzDrzfJ                           Reol
# 63702        63702  22sQUmLhT8umlEhQzDrzfJ                           Reol
# 28105        28105  46RvocxUkMUhCtDxk1BUyT            ILLENIUM;Dana Salah
# 29060        29060  46RvocxUkMUhCtDxk1BUyT            ILLENIUM;Dana Salah
# 23143        23143  46jni4B6gnRB5EbjIEnsf3                      BLOND:ISH
# 25277        25277  46jni4B6gnRB5EbjIEnsf3                      BLOND:ISH
#
#                                                album_name  \
# 30518                                          In My Mind
# 31572                                          In My Mind
# 53361                                          In My Mind
# 31118                                     World Of Walker
# 53114                                     World Of Walker
# 86919                                         How It Goes
# 100373                                        How It Goes
# 67784                        Halloween 2022 Perreo Vol. 1
# 88542                        Halloween 2022 Perreo Vol. 1
# 89493                        Halloween 2022 Perreo Vol. 1
# 55435                                                Piku
# 56134                                                Piku
# 57178                                                Piku
# 65412                                                Piku
# 99077                                                Piku
# 102076                                               Piku
# 67770                                Caribe Mix Reggaeton
# 68537                                Caribe Mix Reggaeton
# 88540                                Caribe Mix Reggaeton
# 89543                                Caribe Mix Reggaeton
# 34093                      Rab Ne Bana Di Jodi (Original)
# 55497                      Rab Ne Bana Di Jodi (Original)
# 51197                         Queda poco para la PAES 2.0
# 67039                         Queda poco para la PAES 2.0
# 68142                         Queda poco para la PAES 2.0
# 88182                         Queda poco para la PAES 2.0
# 89171                         Queda poco para la PAES 2.0
# 21143   Arif Cooper Presents: Up & Live Riddim (2022 R...
# 60043   Arif Cooper Presents: Up & Live Riddim (2022 R...
# 88688   Arif Cooper Presents: Up & Live Riddim (2022 R...
# 74746     As Grandes Décadas Da Música Popular Brasileira
# 96479     As Grandes Décadas Da Música Popular Brasileira
# 62292              Rockin' Around The Christmas Tree 2022
# 64590              Rockin' Around The Christmas Tree 2022
# 99270                                          Flashbacks
# 102271                                         Flashbacks
# 85581                           Orinando Contra el Viento
# 86787                           Orinando Contra el Viento
# 48483             A Juvenile Product of the Working Class
# 82132             A Juvenile Product of the Working Class
# 86974             A Juvenile Product of the Working Class
# 100558            A Juvenile Product of the Working Class
# 20259                  hopeless fountain kingdom (Deluxe)
# 31025                  hopeless fountain kingdom (Deluxe)
# 56035                  hopeless fountain kingdom (Deluxe)
# 57076                  hopeless fountain kingdom (Deluxe)
# 9331                                Mais um Dia (ao Vivo)
# 40119                               Mais um Dia (ao Vivo)
# 26165                 Piano Lullabies for Bedtime, Vol. 3
# 79939                 Piano Lullabies for Bedtime, Vol. 3
# 5867                                                  第六感
# 63702                                                 第六感
# 28105                                               Ashes
# 29060                                               Ashes
# 23143                                   #PlasticFreeParty
# 25277                                   #PlasticFreeParty
#
#                                            track_name  popularity  \
# 30518                                      In My Mind          79
# 31572                                      In My Mind          79
# 53361                                      In My Mind          79
# 31118                                 Man On The Moon          73
# 53114                                 Man On The Moon          73
# 86919                                    Little Bitch          35
# 100373                                   Little Bitch          35
# 67784                                         Jacuzzi           0
# 88542                                         Jacuzzi           0
# 89493                                         Jacuzzi           0
# 55435                                        Bezubaan          53
# 56134                                        Bezubaan          53
# 57178                                        Bezubaan          53
# 65412                                        Bezubaan          53
# 99077                                        Bezubaan          53
# 102076                                       Bezubaan          53
# 67770                                       Loka Loka           0
# 68537                                       Loka Loka           0
# 88540                                       Loka Loka           0
# 89543                                       Loka Loka           0
# 34093                                    Dancing Jodi          50
# 55497                                    Dancing Jodi          50
# 51197                                        Pasarela           0
# 67039                                        Pasarela           0
# 68142                                        Pasarela           0
# 88182                                        Pasarela           0
# 89171                                        Pasarela           0
# 21143   Good Body Wine (2022 Remastered) - Radio Edit           0
# 60043   Good Body Wine (2022 Remastered) - Radio Edit           0
# 88688   Good Body Wine (2022 Remastered) - Radio Edit           0
# 74746                                         Carcará          39
# 96479                                         Carcará          39
# 62292                               Show Me The Magic           0
# 64590                               Show Me The Magic           0
# 99270                                      Flashbacks          67
# 102271                                     Flashbacks          67
# 85581                           Intento Fallido No. 7          38
# 86787                           Intento Fallido No. 7          38
# 48483                               Windspitting Punk          35
# 82132                               Windspitting Punk          35
# 86974                               Windspitting Punk          35
# 100558                              Windspitting Punk          35
# 20259                                Walls Could Talk          77
# 31025                                Walls Could Talk          77
# 56035                                Walls Could Talk          77
# 57076                                Walls Could Talk          77
# 9331                       Vai Valer a Pena - Ao Vivo          47
# 40119                      Vai Valer a Pena - Ao Vivo          47
# 26165                         Angels Watching over Me          28
# 79939                         Angels Watching over Me          28
# 5867                                              第六感          60
# 63702                                             第六感          60
# 28105                                         Reverie          51
# 29060                                         Reverie          51
# 23143                                      Life Is...           0
# 25277                                      Life Is...           0
#
#         duration_ms  explicit  danceability  energy  ...  loudness  mode  \
# 30518        184560     False         0.694  0.7700  ...    -5.335     1
# 31572        184560     False         0.694  0.7700  ...    -5.335     1
# 53361        184560     False         0.694  0.7700  ...    -5.335     1
# 31118        178625     False         0.668  0.8160  ...    -5.648     0
# 53114        178625     False         0.668  0.8160  ...    -5.648     0
# 86919        137773     False         0.444  0.9530  ...    -1.644     1
# 100373       137773     False         0.444  0.9530  ...    -1.644     1
# 67784        184106     False         0.821  0.7360  ...    -4.484     0
# 88542        184106     False         0.821  0.7360  ...    -4.484     0
# 89493        184106     False         0.821  0.7360  ...    -4.484     0
# 55435        341177     False         0.403  0.5600  ...    -7.460     1
# 56134        341177     False         0.403  0.5600  ...    -7.460     1
# 57178        341177     False         0.403  0.5600  ...    -7.460     1
# 65412        341177     False         0.403  0.5600  ...    -7.460     1
# 99077        341177     False         0.403  0.5600  ...    -7.460     1
# 102076       341177     False         0.403  0.5600  ...    -7.460     1
# 67770        210093     False         0.775  0.7940  ...    -4.167     0
# 68537        210093     False         0.775  0.7940  ...    -4.167     0
# 88540        210093     False         0.775  0.7940  ...    -4.167     0
# 89543        210093     False         0.775  0.7940  ...    -4.167     0
# 34093        239647     False         0.704  0.9030  ...    -7.384     0
# 55497        239647     False         0.704  0.9030  ...    -7.384     0
# 51197        193733     False         0.839  0.9070  ...    -4.259     1
# 67039        193733     False         0.839  0.9070  ...    -4.259     1
# 68142        193733     False         0.839  0.9070  ...    -4.259     1
# 88182        193733     False         0.839  0.9070  ...    -4.259     1
# 89171        193733     False         0.839  0.9070  ...    -4.259     1
# 21143        181266     False         0.707  0.9040  ...    -4.091     0
# 60043        181266     False         0.707  0.9040  ...    -4.091     0
# 88688        181266     False         0.707  0.9040  ...    -4.091     0
# 74746        163160     False         0.653  0.6790  ...    -7.354     0
# 96479        163160     False         0.653  0.6790  ...    -7.354     0
# 62292        150412     False         0.569  0.4890  ...    -5.594     0
# 64590        150412     False         0.569  0.4890  ...    -5.594     0
# 99270        183000     False         0.550  0.4480  ...    -7.382     1
# 102271       183000     False         0.550  0.4480  ...    -7.382     1
# 85581        201069      True         0.442  0.8970  ...    -7.100     1
# 86787        201069      True         0.442  0.8970  ...    -7.100     1
# 48483        134800     False         0.284  0.9590  ...    -6.020     0
# 82132        134800     False         0.284  0.9590  ...    -6.020     0
# 86974        134800     False         0.284  0.9590  ...    -6.020     0
# 100558       134800     False         0.284  0.9590  ...    -6.020     0
# 20259        101789      True         0.626  0.4230  ...    -6.035     1
# 31025        101789      True         0.626  0.4230  ...    -6.035     1
# 56035        101789      True         0.626  0.4230  ...    -6.035     1
# 57076        101789      True         0.626  0.4230  ...    -6.035     1
# 9331         297365     False         0.313  0.8690  ...    -4.113     1
# 40119        297365     False         0.313  0.8690  ...    -4.113     1
# 26165        157418     False         0.729  0.0201  ...   -19.780     1
# 79939        157418     False         0.729  0.0201  ...   -19.780     1
# 5867         191624     False         0.675  0.9590  ...    -1.754     1
# 63702        191624     False         0.675  0.9590  ...    -1.754     1
# 28105        299656     False         0.376  0.6920  ...    -4.474     1
# 29060        299656     False         0.376  0.6920  ...    -4.474     1
# 23143        253701     False         0.698  0.8610  ...    -7.210     1
# 25277        253701     False         0.698  0.8610  ...    -7.210     1
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 30518        0.1490      0.176000          0.000011    0.1180   0.1630
# 31572        0.1490      0.176000          0.000011    0.1180   0.1630
# 53361        0.1490      0.176000          0.000011    0.1180   0.1630
# 31118        0.0367      0.055700          0.000001    0.1970   0.5000
# 53114        0.0367      0.055700          0.000001    0.1970   0.5000
# 86919        0.1990      0.023000          0.000000    0.1440   0.6090
# 100373       0.1990      0.023000          0.000000    0.1440   0.6090
# 67784        0.0669      0.091400          0.000000    0.0542   0.9410
# 88542        0.0669      0.091400          0.000000    0.0542   0.9410
# 89493        0.0669      0.091400          0.000000    0.0542   0.9410
# 55435        0.0362      0.354000          0.000006    0.1250   0.1680
# 56134        0.0362      0.354000          0.000006    0.1250   0.1680
# 57178        0.0362      0.354000          0.000006    0.1250   0.1680
# 65412        0.0362      0.354000          0.000006    0.1250   0.1680
# 99077        0.0362      0.354000          0.000006    0.1250   0.1680
# 102076       0.0362      0.354000          0.000006    0.1250   0.1680
# 67770        0.0486      0.162000          0.000000    0.3370   0.8400
# 68537        0.0486      0.162000          0.000000    0.3370   0.8400
# 88540        0.0486      0.162000          0.000000    0.3370   0.8400
# 89543        0.0486      0.162000          0.000000    0.3370   0.8400
# 34093        0.0879      0.015900          0.572000    0.0818   0.6510
# 55497        0.0879      0.015900          0.572000    0.0818   0.6510
# 51197        0.0453      0.101000          0.000000    0.3320   0.7370
# 67039        0.0453      0.101000          0.000000    0.3320   0.7370
# 68142        0.0453      0.101000          0.000000    0.3320   0.7370
# 88182        0.0453      0.101000          0.000000    0.3320   0.7370
# 89171        0.0453      0.101000          0.000000    0.3320   0.7370
# 21143        0.1480      0.130000          0.000000    0.2570   0.8230
# 60043        0.1480      0.130000          0.000000    0.2570   0.8230
# 88688        0.1480      0.130000          0.000000    0.2570   0.8230
# 74746        0.0714      0.673000          0.000441    0.6080   0.8770
# 96479        0.0714      0.673000          0.000441    0.6080   0.8770
# 62292        0.0400      0.238000          0.000000    0.2900   0.5430
# 64590        0.0400      0.238000          0.000000    0.2900   0.5430
# 99270        0.0314      0.879000          0.000000    0.0734   0.4900
# 102271       0.0314      0.879000          0.000000    0.0734   0.4900
# 85581        0.0439      0.013000          0.012000    0.1680   0.5750
# 86787        0.0439      0.013000          0.012000    0.1680   0.5750
# 48483        0.1230      0.001420          0.000146    0.0866   0.6650
# 82132        0.1230      0.001420          0.000146    0.0866   0.6650
# 86974        0.1230      0.001420          0.000146    0.0866   0.6650
# 100558       0.1230      0.001420          0.000146    0.0866   0.6650
# 20259        0.0513      0.128000          0.000000    0.1800   0.5710
# 31025        0.0513      0.128000          0.000000    0.1800   0.5710
# 56035        0.0513      0.128000          0.000000    0.1800   0.5710
# 57076        0.0513      0.128000          0.000000    0.1800   0.5710
# 9331         0.0508      0.133000          0.001740    0.7030   0.2210
# 40119        0.0508      0.133000          0.001740    0.7030   0.2210
# 26165        0.0465      0.994000          0.927000    0.1060   0.2800
# 79939        0.0465      0.994000          0.927000    0.1060   0.2800
# 5867         0.0835      0.008930          0.000085    0.3250   0.8350
# 63702        0.0835      0.008930          0.000085    0.3250   0.8350
# 28105        0.0558      0.019700          0.000393    0.1110   0.0903
# 29060        0.0558      0.019700          0.000393    0.1110   0.0903
# 23143        0.0344      0.000237          0.471000    0.0758   0.1690
# 25277        0.0344      0.000237          0.471000    0.0758   0.1690
#
#           tempo  time_signature        track_genre
# 30518   125.905               4                edm
# 31572   125.905               4            electro
# 53361   125.905               4              house
# 31118   129.971               4            electro
# 53114   129.971               4              house
# 86919   189.790               4               punk
# 100373  189.790               4                ska
# 67784    93.008               4              latin
# 88542    93.008               4             reggae
# 89493    93.008               4          reggaeton
# 55435   155.701               4             indian
# 56134   155.701               4          indie-pop
# 57178   155.701               4              indie
# 65412   155.701               4              k-pop
# 99077   155.701               4  singer-songwriter
# 102076  155.701               4         songwriter
# 67770    94.018               4              latin
# 68537    94.018               4             latino
# 88540    94.018               4             reggae
# 89543    94.018               4          reggaeton
# 34093   131.988               4               folk
# 55497   131.988               4             indian
# 51197   121.048               4            hip-hop
# 67039   121.048               4              latin
# 68142   121.048               4             latino
# 88182   121.048               4             reggae
# 89171   121.048               4          reggaeton
# 21143    86.708               5          dancehall
# 60043    86.708               5            j-dance
# 88688    86.708               5             reggae
# 74746   130.964               4                mpb
# 96479   130.964               4              samba
# 62292   123.573               4              j-pop
# 64590   123.573               4               jazz
# 99270    99.713               4  singer-songwriter
# 102271   99.713               4         songwriter
# 85581   102.536               4          punk-rock
# 86787   102.536               4               punk
# 48483   174.296               4           hardcore
# 82132   174.296               4          power-pop
# 86974   174.296               4               punk
# 100558  174.296               4                ska
# 20259    95.162               4              dance
# 31025    95.162               4            electro
# 56035    95.162               4          indie-pop
# 57076    95.162               4              indie
# 9331    127.875               4             brazil
# 40119   127.875               4             gospel
# 26165    78.051               4             disney
# 79939    78.051               4              piano
# 5867    134.017               4              anime
# 63702   134.017               4             j-rock
# 28105   173.899               4                dub
# 29060   173.899               4            dubstep
# 23143   123.004               4         deep-house
# 25277   123.004               4              disco
#
# [56 rows x 21 columns]

# %%
# save to excel so that I can see it properly
output_path2 = os.path.join(os.getcwd(), "datasets", "dup_sample.xlsx")
tracks_df_dup.to_excel(output_path2, index = False)

# %%
# ok the issue is that there aren't duplicate tracks as such
# if a track has multiple genres it has a record for the first genre, a record for the second genre etc.
# one solution to fix this would be to make the genre column 'wide' 
# i.e. a column for pop that has a 1 or 0 if the track has the pop 'genre', a column 'rock' (1 or 0 if track is rock) etc.

# what are the distinct values on the track_genre field?
genres = tracks_df['track_genre'].value_counts().reset_index()

# %%
output_path3 = os.path.join(os.getcwd(), "datasets", "genres.xlsx")
genres.to_excel(output_path3, index = False)

# %%
# ok, it appears there are 114 different genres, with 1000 tracks for each, this means that there will be a bias to mitigate against later

# %%
# take the music of a specific artist to see if there is anything else to watch out for

cb_df = tracks_df[
    tracks_df['artists'].str.contains('chris', case=False, na=False) &
    tracks_df['artists'].str.contains('brown', case=False, na=False)
]

output_path4 = os.path.join(os.getcwd(), "datasets", "cb.xlsx")
cb_df.to_excel(output_path4, index = False)

# %%
# yes, the song 'Algo me gusta de ti' is a duplicate because it appears on multiple different albums.
# The only thing that differs for it is the popularity and the genre, so maybe the most popular version could be taken to simplify things

# %%
# make the genre column wide

# first replace the hyphens with underscores
tracks_df['track_genre_cln']  = tracks_df['track_genre'].str.replace('-','_', regex = False)

# check that it worked as desired
test = tracks_df[['track_genre', 'track_genre_cln']].drop_duplicates()
print(test)

# all good
# Out:
#         track_genre track_genre_cln
# 0          acoustic        acoustic
# 1000       afrobeat        afrobeat
# 2000       alt-rock        alt_rock
# 3000    alternative     alternative
# 4000        ambient         ambient
# ...             ...             ...
# 109000       techno          techno
# 110000       trance          trance
# 111000     trip-hop        trip_hop
# 112000      turkish         turkish
# 113000  world-music     world_music
#
# [114 rows x 2 columns]

# %%
# convert the cln column to a wide
tracks_df['track_genre_cln'] = tracks_df['track_genre_cln'].astype('category')
print(tracks_df.info()) # worked as desired
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
#  21  track_genre_cln   114000 non-null  category
# dtypes: bool(1), category(1), float64(9), int64(6), object(5)
# memory usage: 17.6+ MB
# None

# %%
# I need to make sure that the first 20 columns (all except the track_genre columns) are a unique primary key
cols = tracks_df.columns.tolist()
print(cols)

column_names = ['track_id', 'artists', 'album_name', 'track_name', 'popularity', 'duration_ms'
                , 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness'
                , 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

# just show these columns in the dataframe
tracks_df_subset = tracks_df[column_names]

# remove the duplicates
tracks_df_subset_dedup = tracks_df_subset.drop_duplicates()

# now check whether there are any duplicate track_ids
test = tracks_df_subset_dedup['track_id'].value_counts().reset_index()
print(test)
test.columns = ['track_id', 'num_occ']
test2 = test['num_occ'].value_counts().reset_index()
print(test2)
# still 720 with a duplicate
# isolate them

test3 = test[test['num_occ'] == 2]
print(test3)


test4 = list(test3['track_id'])
print(test4)


test5 = tracks_df_subset_dedup[tracks_df_subset_dedup['track_id'].isin(test4)]
print(test5)

# check whether there are any duplicates in the dataframe
#duplicates_exist = tracks_df_subset.duplicated().any()
#print("Any duplicates:", duplicates_exist)

# gather the duplicated rows for analysis
#duplicated_rows = tracks_df_subset[tracks_df_subset.duplicated(keep=False)]


# take a sample of the duplicated rows as there seem to be a lot
#duplicated_rows_samp = duplicated_rows.sample(n = 5000, random_state = 38) 

#output them for easy review
output_path6 = os.path.join(os.getcwd(), "datasets", "duplicates5.xlsx")
test5.to_excel(output_path6, index = False)


# there are also duplicates on the popularity column
# Out:
# ['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'track_genre', 'track_genre_cln']
#                      track_id  count
# 0      2ji53kdnw4UtV6PIt94MLq      2
# 1      30hKEQLgr25oI91btWLvCi      2
# 2      25ysC9uw0bpwgcxOhnrwjk      2
# 3      3TNUCQeXAALQrTw7ANSEoB      2
# 4      7nudwi49ZHlgt6AtNNgVnJ      2
# ...                       ...    ...
# 89736  5wMkhfu3oYYmFimOGzeFt2      1
# 89737  64BdW5aHuB3C0QP3qjBJVi      1
# 89738  1pBc7W7UQacUeQ6kBVlN9f      1
# 89739  39So2wAM6l3XKWDf5XjiIz      1
# 89740  01MVOl9KtVTNfFiBU9I7dc      1
#
# [89741 rows x 2 columns]
#    num_occ  count
# 0        1  89021
# 1        2    720
#                    track_id  num_occ
# 0    2ji53kdnw4UtV6PIt94MLq        2
# 1    30hKEQLgr25oI91btWLvCi        2
# 2    25ysC9uw0bpwgcxOhnrwjk        2
# 3    3TNUCQeXAALQrTw7ANSEoB        2
# 4    7nudwi49ZHlgt6AtNNgVnJ        2
# ..                      ...      ...
# 715  2hnMS47jN0etwvFPzYk11f        2
# 716  25tFLO2t30VhgAqLrjFMfs        2
# 717  0xad4yuDkjVlI53EIIkoIW        2
# 718  51R9caoQ0l5bZ1ahBeqJq9        2
# 719  5OOPYQor9kRh18B73f2Vci        2
#
# [720 rows x 2 columns]
# ['2ji53kdnw4UtV6PIt94MLq', '30hKEQLgr25oI91btWLvCi', '25ysC9uw0bpwgcxOhnrwjk', '3TNUCQeXAALQrTw7ANSEoB', '7nudwi49ZHlgt6AtNNgVnJ', '6FxdAycUNPT8gHH5JhG2xI', '0tWAGWvw3WWySN5fXfW1jO', '4YsKbWkeQD3SoKVhbJ5fPu', '0P2HpJnPusLZ01iBlPG2HR', '0BkfeemCDp8WmuKVnrwBaN', '3OB8tXG4qxdvs5Y9cZDsMa', '4zBXE3hymk2qz1LIk9Swph', '6zJob7NjhfptpxyO0SgTyu', '0nlxkDzyZPBFxaFQqoNdYy', '2zQt5C0AIv27RhfJCRZdZ4', '0C6dSPCqwKqwos6s1CrDrh', '5gUxxioIeJdr61AgjVYznI', '5fClRRa7P9nPIpstj50veV', '1QbOvACeYanja5pbnJbAmk', '7oMO1B9CB4ZPYPLeVe32OY', '4VWlZb7Xiq1Im9Abzhe9fp', '4GxFCitrF1Fu9qycAv8A3R', '3L6EOy5OG9JetMXAbEJQu9', '491c4G5XxA8I80zNvR1rLR', '6eNbZHgy85Hsw6JGME1j6P', '6CW9qtzZpHZ3o39BYlpU0x', '0vB4Vd6PtkJSEnWsmqATnZ', '6oMZhY0f1ReI6AJDDYfuSb', '2lCsTpkit36cAJ0pSEpzr4', '2qESE1ZeWly7I3YjyTXmXh', '0f0gfm6wHjhqrBMHBn9Ajr', '0z5x3VmmQ7cyTeOP7VAf3T', '1l1ra0gsPlpnDOc4HdkKZU', '6G2IXaarVeVde7CaMOxvNh', '42GuKw49pPxNAkIhWGwgFs', '1cKtQSJ8pMVErEIJzTYsSe', '52VgFTD7QmOmAPJZfxnPVK', '1SJkTuUNKe4rYQgX8wmqku', '4YEA9DzQt60W0Q34Dw1O5f', '2jRISGsO4RTm9CQVb1Jusn', '6jmf4OxSGzdgthZruXtcqu', '3kQhWtoluFHPbcBC6gyYrZ', '5hljqZrl0h7RcIhUnOPuve', '1FuZ8H0Ts3799ZNVN5ZcSZ', '4PwkiQyE09iOcKameCkQAF', '7gu0zaym9C9Kp1va4ZeYXR', '78iVPIyFgGjQ0g0TmDWYtQ', '1Wt8OoQoQ2DsoPHs0TdOHn', '3XDeeP9wBZzGhIPZmLfEEx', '2GtksLOwApBFKXsm4jsw8o', '3pvXNqXnuDJgkG1ZDwhQ9E', '2IoSxedPj3lZVul8qUyWZF', '4k2AjlWruIygEiZyJEy01I', '05UkW0aWSlpxcOlT3NtJ1N', '0X9MmC3La4fWsaceYFHwWK', '11jMqNuaE2vTsBBjESguoL', '1gCP90gwbynaN4zaaMQU7L', '5ygEUpyZy5qtZ1423zymBW', '56OLAHwj0Y4wqJFfsf08rD', '2Ns9vtFyKhGoI0vCFLHQOR', '1PHqmiRTZnqHZkkR9Zjtvh', '1FGNS493UKaQOSLLy5JBId', '2EiVLz6irHr0sYvhiHubCh', '6zjFDWbTd9W8BAYUfDOc4B', '4HGq8ZzrPOtXxNEXN4XGFu', '79GBhyAo9KAuMH3oztkJjb', '7cEbICGWeFyBTmijsRtbjr', '2einB00Doep8LZImPipb9r', '5r0x87jwTbkVjA3FQNOykz', '1zx6GSqLYI2ynzAHnPRKBR', '0RTqRMNHselkQSCxbnsGYz', '3LpIXpas8lnDrUDqOYyB7u', '3MZm4t1kRJ2e5JyaYQpjrF', '6VuztO5yaKP4VjqSkZxpan', '3AaGCSpUFAmtB1XGxz5IWk', '17M1JFSr2eEvo5dQnCIQim', '4KPi4VNvPOfKqIp1sx19Xf', '05ztmc9JMq8pYE2GyY72Zd', '0gplL1WMoJ6iYaPgMCL0gX', '1UwUhKmFxGKs59xiWO60Sx', '42Jkqzhm5Y7ab7f1d22GTq', '6VObnIkLVruX4UVyxWhlqm', '0j2BydmlwcMqffV08hFDyI', '2zYzyRzz6pRmhPzyfMEC8s', '2fB4EWHpiADO2Bv2Dzenmi', '1eV81a6H4xDdpi8r2C4tQT', '0VpcSl7QEqVEiAZLQFW0rm', '5H0kIgpWNZm9HF6VkU4dow', '3Rn21K5Te3TUM0AcFtisuX', '48CKzGWOC65n8a8kdANJV8', '5kNCog1amNsI8z2iD5634p', '1ufGqwim7RHxVsdaxuLmAY', '4kLIAQN2z1Uh0NvpNgz6jF', '2LawezPeJhN4AWuSB0GtAU', '0EKqoSFmZW4dqaJvlEJtMe', '5H0rkrwdQytofgRjhZe9XF', '0qJOO0qpBFmR1vXf4rMRuj', '4iF2TMFaiJwEHecDNavRU9', '2shdj27ClUe4ETiBQXGLdQ', '21NimLGgXhfEbIXsIiPHXy', '17eeKDTWiREsr23gIYahtE', '582QmuQapDg7uo1jcAKsgN', '1VhGRC4yzcDFBM4yQSpUGg', '3aTJREDBpFWYhR5m4i48jO', '2DOdnZIgqRPq95tDc26Kgm', '0IQBwszytBLb7GsRm0GwKz', '0j5pajJcigjdwO4c8ZS19b', '6S2YyQWrTkJG88HJRtgbWu', '7DGiwSAi7JqgndlMXcXTHE', '0dkvbYmXYEPK7gGMdytmfI', '1235OqEAiQvJp7jAmc96dN', '4QdV0xTf6iPrrtVNf2Gsnm', '6jBjT54uoj1ortBRNOKXaj', '7x7i3XBKSM4AoLoPymDuh9', '14dJexYlvd3t3XAtD1pYW1', '0OZYXc58HooMgBNWyp6cuO', '0fYVliAYKHuPmECRs1pbRf', '1xj7USYBhbTPsZDiy8gVcb', '3tgVp3M5fgSNhEUE1iMILQ', '0rGKn11s2zrmePIA82ldEP', '66llZ6MdjJy5q2jWwgJpcW', '4HMfyF1N7spvVdWuAzyk3C', '67f867INYgEaahq90kqeKE', '3nJtKV23cLqdMzurBX49Tq', '3RXAcz7Sa6JDZSxcH1EEQ6', '6VQW8Ye28Crwz90BIexsrF', '26ZzSLUJMmYp5u1hDELEWH', '6dsmAUGQAng00srCMvfd8z', '1VyiUi0mRnSKgtHa5dBoUd', '0pdKRp2sUthTPe7RLWpPqQ', '72R0X0h8YaxYNpegeoOl0M', '6vmdV1NsKisfobiqyg2kG3', '2XzRnzuIgpZGqco2rMTQbS', '27LtwN20Rvhi6LVmUaaucZ', '6gqZzQyJfKqdc9boOILz4x', '74PyndGWYtfs86n60lAsYW', '3xMQOd1C3TXsjQ3pmzOmkC', '1lYHv3SEkE6wKfZRe0HMOG', '32kz93hA4ac01juOqcSItF', '4CwqO0iNCHRA4fATRPs79R', '4KMR0q5skgPUVS1e1IgCJJ', '20j7B6mL9gnNvG3ic6Vwh5', '0Z5ok0QLLttAKsujOZYOXf', '29RKQaclcGpj1stafjGHAZ', '1gWtHDe403RuyZqhvSRcv8', '2Mw8xQJpIDAgrktDXEqxCs', '6CV34A2xO8SOZw4RqSSUOe', '1PXsUXSM3LF2XNSkmIldPb', '0jyk4jjgm4j1gUqMg4Z7Tw', '3CvfYeaJX8JAT1tF5IzVlG', '5LXaBBZePqShzKxM6b9RFU', '5YaskwnGDZFDRipaqzbwQx', '5ARrtxJLVCeTv5TWo1oKgC', '7n6FiTKMPLDZNjvmhVux ...
#                       track_id                      artists  \
# 29      2qESE1ZeWly7I3YjyTXmXh                   Jason Mraz
# 130     72R0X0h8YaxYNpegeoOl0M                    Parachute
# 1013    3BGxXQJWeLAEcwNKRFUxYA          BaianaSystem;BNegão
# 1039    2zQt5C0AIv27RhfJCRZdZ4                 BaianaSystem
# 1096    3MZm4t1kRJ2e5JyaYQpjrF                Jackie Mittoo
# ...                        ...                          ...
# 113037  1EWRXz6c0WPKae8vziEnZi                 Chris Tomlin
# 113108  6CW9qtzZpHZ3o39BYlpU0x  Bethel Music;Bethany Wohrle
# 113293  6HRU0CPcG0q3Dq8XVBWacL    Bethel Music;Josh Baldwin
# 113347  3ExKJt4K8duUfEG49QWzPi   Bethel Music;Jeremy Riddle
# 113456  2ZUEopklc3lUm4OXUPB6WS    Bethel Music;Brandon Lake
#
#                                 album_name  \
# 29                  Perfect Christmas Hits
# 130                         The Way It Was
# 1013                   ATO 1: Navio Pirata
# 1039                          Duas Cidades
# 1096       The Keyboard King at Studio One
# ...                                    ...
# 113037              Santa's Christmas List
# 113108                         Living Hope
# 113293  Stand In Your Love (Radio Version)
# 113347           For the Sake of the World
# 113456      Too Good To Not Believe (Live)
#
#                                 track_name  popularity  duration_ms  explicit  \
# 29                       Winter Wonderland           0       131760     False
# 130                         Kiss Me Slowly          61       235813     False
# 1013                            Reza Forte          38       232826     False
# 1039                Jah Jah Revolta, Pt. 2          39       309493     False
# 1096                           Black Organ          34       191506     False
# ...                                    ...         ...          ...       ...
# 113037  Joy To The World (Unspeakable Joy)           3       230720     False
# 113108                         Living Hope          53       406346     False
# 113293  Stand In Your Love (Radio Version)          56       221333     False
# 113347               This Is Amazing Grace          50       452013     False
# 113456      Too Good To Not Believe - Live          54       633462     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 29             0.620   0.309    5    -9.209     1       0.0495       0.78800
# 130            0.470   0.801    9    -6.426     1       0.0352       0.07580
# 1013           0.844   0.915    0    -4.060     0       0.1290       0.39300
# 1039           0.776   0.800    8    -4.704     0       0.0438       0.00631
# 1096           0.837   0.598    1    -9.047     0       0.1810       0.39100
# ...              ...     ...  ...       ...   ...          ...           ...
# 113037         0.418   0.876    2    -5.157     1       0.0529       0.00187
# 113108         0.414   0.712    9    -6.815     1       0.0379       0.04860
# 113293         0.461   0.802    0    -4.448     1       0.0325       0.11200
# 113347         0.437   0.735    0    -6.606     1       0.0301       0.00206
# 113456         0.355   0.734    0    -8.221     1       0.0509       0.00177
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 29              0.000000    0.1460    0.664  145.363               4
# 130             0.000035    0.2180    0.431  173.920               4
# 1013            0.002380    0.0847    0.872  145.997               4
# 1039            0.073100    0.3500    0.583  143.989               4
# 1096            0.238000    0.0598    0.983  145.219               4
# ...                  ...       ...      ...      ...             ...
# 113037          0.000000    0.8290    0.341  128.033               4
# 113108          0.000000    0.5290    0.185  143.957               4
# 113293          0.000000    0.1160    0.342  144.518               4
# 113347          0.000022    0.7010    0.145   98.923               4
# 113456          0.000000    0.0965    0.237  143.964               4
#
# [1440 rows x 19 columns]

# %%
# a list of identified duplicates
dups = ['7tNzd03v3T5aU7P1UpeuYF','7Fo51x6cURFo9jCzcv7WOL','4WRoLfCYJ4sLMhXgQJnI2N','7ITEWyZlNF2bpDPsHan8Ea','7EkWXAI1wn8Ii883ecd9xr',
        '4Q2pNhiQ5KtzuXd0GIbRiz','5psIcronqyDyYWBVFNSyVh','5X1VGqaNrpXC8HBPEA4uDT','59mrqUmhpmcfUns8BKkV30','2jdAk8ATWIL3dwT47XpRfu',
        '7aonAWn0J0AJ47ZU9WHCXC','2KH9tWMNpKRIfEJlx8FJbk','5oDkgd1jpgrT0wcHwtsSQq','2SFhJe79faMbb5fgEFJGg0','4wSMi5urWxpBPbnWqfI1Ht',
        '0PF7SVd93G602xdi8SVyEz','1yEBMvOYbhJJTX7x3iW41O','3MADBbqQFspWXZrTytVLfO','7aQT5OB4zEgyyxfRDbOBIt']

# filter for them
dups2 = tracks_df_subset[tracks_df_subset['track_id'].isin(dups)]

# output to excel for a quick look
output_path6 = os.path.join(os.getcwd(), "datasets", "duplicates2.xlsx")
dups2.to_excel(output_path6, index = False)

# ok, they're all duplicates there

# %%
# compare that with a handful of them in the original data frame
dups3 = ['0PF7SVd93G602xdi8SVyEz','1yEBMvOYbhJJTX7x3iW41O','2jdAk8ATWIL3dwT47XpRfu']
# filter for them
dups4 = tracks_df[tracks_df['track_id'].isin(dups)]

# output to excel for a quick look
output_path7 = os.path.join(os.getcwd(), "datasets", "duplicates3.xlsx")
dups4.to_excel(output_path7, index = False)

# %%
tracks_df['value'] = 1  # This will be used as the value for pivot

# Pivot only track_id + genre
tracks_df2 = tracks_df.pivot_table(
    index='track_id',
    columns='track_genre_cln',
    values='value',
    aggfunc='max',
    fill_value=0
).reset_index()

# Merge with metadata
#df_wide = df_metadata.merge(df_pivot, on='track_id', how='left')
# Out:
# C:\Users\Anne\AppData\Local\Temp\ipykernel_2900\269178420.py:4: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tracks_df2 = tracks_df.pivot_table(

# %%
output_path5 = os.path.join(os.getcwd(), "datasets", "tracksdf2.xlsx")
tracks_df2.to_excel(output_path5, index = False)

# %%
# look at one of the popularity duplicates in the original dataset
testa = tracks_df[tracks_df['track_id'] == '00YwP3wJWiG8IxAA7OS9lo']

output_path6 = os.path.join(os.getcwd(), "datasets", "testa.xlsx")
testa.to_excel(output_path6, index = False)

# interestingly, it is the same song but has different genres

# %%
# solution
# make one dataset of unique track_id, trackname, artist album etc. EXCEPT the genre, and just take the max of popularity
# make a second dataset of unique track_id, trackname, artist album, all the unique genres linked to it, but making sure to leave out the popularity part
# make the second dataset wide, then left join it onto the first
# then it'll be clean and red for exploratory analysis

# %%
# make the first dataset
tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
#  21  track_genre_cln   114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(6)
# memory usage: 18.4+ MB

# %%
# make the first dataset
tracks_df_build1 = tracks_df[['track_id', 'artists', 'album_name', 'track_name', 'popularity', 'duration_ms'
                            , 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness'
                            , 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]
tracks_df_build1.info() # 1140k records
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          114000 non-null  object
#  1   artists           113999 non-null  object
#  2   album_name        113999 non-null  object
#  3   track_name        113999 non-null  object
#  4   popularity        114000 non-null  int64
#  5   duration_ms       114000 non-null  int64
#  6   explicit          114000 non-null  bool
#  7   danceability      114000 non-null  float64
#  8   energy            114000 non-null  float64
#  9   key               114000 non-null  int64
#  10  loudness          114000 non-null  float64
#  11  mode              114000 non-null  int64
#  12  speechiness       114000 non-null  float64
#  13  acousticness      114000 non-null  float64
#  14  instrumentalness  114000 non-null  float64
#  15  liveness          114000 non-null  float64
#  16  valence           114000 non-null  float64
#  17  tempo             114000 non-null  float64
#  18  time_signature    114000 non-null  int64
# dtypes: bool(1), float64(9), int64(5), object(4)
# memory usage: 15.8+ MB

# %%
# drop the duplicates
tracks_df_build1a = tracks_df_build1.drop_duplicates()
tracks_df_build1a.info() # 90k records
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90461 entries, 0 to 113999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          90461 non-null  object
#  1   artists           90460 non-null  object
#  2   album_name        90460 non-null  object
#  3   track_name        90460 non-null  object
#  4   popularity        90461 non-null  int64
#  5   duration_ms       90461 non-null  int64
#  6   explicit          90461 non-null  bool
#  7   danceability      90461 non-null  float64
#  8   energy            90461 non-null  float64
#  9   key               90461 non-null  int64
#  10  loudness          90461 non-null  float64
#  11  mode              90461 non-null  int64
#  12  speechiness       90461 non-null  float64
#  13  acousticness      90461 non-null  float64
#  14  instrumentalness  90461 non-null  float64
#  15  liveness          90461 non-null  float64
#  16  valence           90461 non-null  float64
#  17  tempo             90461 non-null  float64
#  18  time_signature    90461 non-null  int64
# dtypes: bool(1), float64(9), int64(5), object(4)
# memory usage: 13.2+ MB

# %%
# now just take all values and the maximum populatiry value

# Define which column to aggregate
agg_col = 'popularity'

# Group by all other columns
group_cols = [c for c in tracks_df_build1a.columns if c != agg_col]

# Aggregate
tracks_df_build1b = tracks_df_build1a.groupby(group_cols, as_index=False)[agg_col].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       4 agg_col = 'popularity'
#       6 # Group by all other columns
# ----> 7 group_cols = [c for c in tracks_df_build1a.columns if c != agg_col]
#       9 # Aggregate
#      10 tracks_df_build1b = tracks_df_build1a.groupby(group_cols, as_index=False)[agg_col].max()
#
# NameError: name 'tracks_df_build1a' is not defined

# %%
# output and make sure I'm happy with it
tracks_df_build1b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89740 entries, 0 to 89739
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          89740 non-null  object
#  1   artists           89740 non-null  object
#  2   album_name        89740 non-null  object
#  3   track_name        89740 non-null  object
#  4   duration_ms       89740 non-null  int64
#  5   explicit          89740 non-null  bool
#  6   danceability      89740 non-null  float64
#  7   energy            89740 non-null  float64
#  8   key               89740 non-null  int64
#  9   loudness          89740 non-null  float64
#  10  mode              89740 non-null  int64
#  11  speechiness       89740 non-null  float64
#  12  acousticness      89740 non-null  float64
#  13  instrumentalness  89740 non-null  float64
#  14  liveness          89740 non-null  float64
#  15  valence           89740 non-null  float64
#  16  tempo             89740 non-null  float64
#  17  time_signature    89740 non-null  int64
#  18  popularity        89740 non-null  int64
# dtypes: bool(1), float64(9), int64(5), object(4)
# memory usage: 12.4+ MB

# %%
# it has one less record than the main dataset, investigate why
missing_in_df1 = tracks_df_build1b[~tracks_df_build1b['track_id'].isin(tracks_df['track_id'])]
missing_in_df2 = tracks_df[~tracks_df['track_id'].isin(tracks_df_build1b['track_id'])]
print(missing_in_df1)
print(missing_in_df2)
# Out:
# Empty DataFrame
# Columns: [track_id, artists, album_name, track_name, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, popularity]
# Index: []
#        Unnamed: 0                track_id artists album_name track_name  \
# 65900       65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN
#
#        popularity  duration_ms  explicit  danceability  energy  ...  mode  \
# 65900           0            0     False         0.501   0.583  ...     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature  track_genre  track_genre_cln
# 65900  138.391               4        k-pop            k_pop
#
# [1 rows x 22 columns]

# %%
testb = tracks_df[tracks_df['track_id'] == '1kR4gIb7nGxHPI3D2ifs59']

output_path7 = os.path.join(os.getcwd(), "datasets", "testb.xlsx")
testb.to_excel(output_path7, index = False)

# it's just a solitary k-pop song without a trackname, artist, album or popularity value. So just exclude it from the dataset

# %%
tracks_df_build1b['track_id'].nunique()
# all good
# Out:
# 89740

# %%
# moving on to the second dataset
tracks_df_build2 = tracks_df[['track_id', 'artists', 'album_name', 'track_name', 'track_genre_cln']]
tracks_df_build2.info() # 114k records
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   track_id         114000 non-null  object
#  1   artists          113999 non-null  object
#  2   album_name       113999 non-null  object
#  3   track_name       113999 non-null  object
#  4   track_genre_cln  114000 non-null  object
# dtypes: object(5)
# memory usage: 4.3+ MB

# %%
tracks_df_build2a = tracks_df_build2.drop_duplicates()
tracks_df_build2a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113550 entries, 0 to 113999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   track_id         113550 non-null  object
#  1   artists          113549 non-null  object
#  2   album_name       113549 non-null  object
#  3   track_name       113549 non-null  object
#  4   track_genre_cln  113550 non-null  object
# dtypes: object(5)
# memory usage: 5.2+ MB

# %%
check_a = tracks_df[tracks_df['track_id'].isin(['6hNjGPE8S1No2Evu4aPLjL', '1gQ0W0XKnOUpmcD5Vzs8e7', '2R3LQndjqKf8CIuPTSiI8p', '476V2d6iA2tWXgQboKmTtA', '5zTirec9tIsSVNgBSUmFxU', 
                                                '5r0x87jwTbkVjA3FQNOykz', '3RXAcz7Sa6JDZSxcH1EEQ6', '6aGP0AAF8iLyoGdLRpuVoZ', '7fpym9dJ7HFNgOxk2x8iMb', '2syQ0f4SAQdzvlAewPl1DJ', 
                                                ])]
df_xl(check_a)
# Out:
# DataFrame saved to: c:\Users\Anne\OneDrive\Desktop\Files\_VSC_repositories\spotify_tracks\datasets\data_output_a.xlsx

# %%
# it looks like all the tracks with a different performance value, also have different values for the genre.
# it makes sense in the interest of not excluding information, to keep all genres

# so, make the dataset wide
# Create dummy variables (one-hot encoding)
dummies = pd.get_dummies(tracks_df_build2a['track_genre_cln'])

# Concatenate the dummy columns to the original DataFrame
df_wide = pd.concat([tracks_df_build2a.drop(columns=['track_genre_cln']), dummies], axis=1)

# Aggregate to remove duplicates — sum ensures 1 if category appears
tracks_df_build2b = df_wide.groupby(['track_id', 'artists', 'album_name', 'track_name'], as_index=False).sum()

# %%
tracks_df_build2b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89740 entries, 0 to 89739
# Columns: 118 entries, track_id to world_music
# dtypes: int64(114), object(4)
# memory usage: 80.8+ MB

# %%
# left join dataset 2 onto dataset 1 and do some sampling to test the popularity and category cleanings

tracks_df_cln = tracks_df_build1b.merge(tracks_df_build2b, on = ['track_id', 'artists', 'album_name','track_name'], how = 'left')
tracks_df_cln.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89740 entries, 0 to 89739
# Columns: 133 entries, track_id to world_music
# dtypes: bool(1), float64(9), int64(119), object(4)
# memory usage: 90.5+ MB

# %%
# take a sample of it and clash against the original dataframe
tracks_df_cln_sample = tracks_df_cln[tracks_df_cln['track_id'].isin(['6hNjGPE8S1No2Evu4aPLjL', '1gQ0W0XKnOUpmcD5Vzs8e7', '2R3LQndjqKf8CIuPTSiI8p', '476V2d6iA2tWXgQboKmTtA', '5zTirec9tIsSVNgBSUmFxU', 
                                                '5r0x87jwTbkVjA3FQNOykz', '3RXAcz7Sa6JDZSxcH1EEQ6', '6aGP0AAF8iLyoGdLRpuVoZ', '7fpym9dJ7HFNgOxk2x8iMb', '2syQ0f4SAQdzvlAewPl1DJ', 
                                                ])]
df_xl(tracks_df_cln_sample)

tracks_df_sample2 = tracks_df[tracks_df['track_id'].isin(['6hNjGPE8S1No2Evu4aPLjL', '1gQ0W0XKnOUpmcD5Vzs8e7', '2R3LQndjqKf8CIuPTSiI8p', '476V2d6iA2tWXgQboKmTtA', '5zTirec9tIsSVNgBSUmFxU', 
                                                '5r0x87jwTbkVjA3FQNOykz', '3RXAcz7Sa6JDZSxcH1EEQ6', '6aGP0AAF8iLyoGdLRpuVoZ', '7fpym9dJ7HFNgOxk2x8iMb', '2syQ0f4SAQdzvlAewPl1DJ', 
                                                ])]

df_xl(tracks_df_sample2)
# Out:
# DataFrame saved to: c:\Users\Anne\OneDrive\Desktop\Files\_VSC_repositories\spotify_tracks\datasets\data_output_b.xlsx
# DataFrame saved to: c:\Users\Anne\OneDrive\Desktop\Files\_VSC_repositories\spotify_tracks\datasets\data_output_c.xlsx

# %%
# perfectly as desired from sampling

# %%
# but there is also the issue of duplicate tracks across albums
check = tracks_df_cln[tracks_df_cln['track_name']=='Algo Me Gusta De Ti']
df_xl(check)
# Out:
# DataFrame saved to: c:\Users\Anne\OneDrive\Desktop\Files\_VSC_repositories\spotify_tracks\datasets\data_output_e.xlsx

# %%
# explore a solution for this
# how much duplication is there across track_name, artists, duration_ms
